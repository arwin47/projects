# %% [markdown]
# ## Media Mix Modelling
# Here, MMM is implemented using `lightweight_mmm`.
#
# **Overview:**
# Media mix models are statistical models that are used to understand the Return On Investment(ROI) of various media channels and to optimiza the budget. The dataset will be `media spends` (independent variables) and `sales/revenue` (dependent variable).
#
# This exercise uses a [dataset available in kaggle](https://www.kaggle.com/datasets/mediaearth/traditional-and-digital-media-impact-on-sales/data).

# %% [markdown]
# ### Importing Required Libraries

# %%
import pandas as pd

# Access datasets from Kaggle
import kagglehub  # Interface to download datasets from Kaggle
from kagglehub import KaggleDatasetAdapter  # Adapter to interact with Kaggle datasets

# Import jax.numpy and any other library we might need.
import jax.numpy as jnp
import numpyro

# Import the relevant modules of the library
from lightweight_mmm import lightweight_mmm
from lightweight_mmm import optimize_media
from lightweight_mmm import plot
from lightweight_mmm import preprocessing
from lightweight_mmm import utils

# %% [markdown]
# ### Importing Data

# %%
# Load the dataset from Kaggle using the KaggleHub adapter in pandas format
data = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "mediaearth/traditional-and-digital-media-impact-on-sales",  # Dataset slug
    "mediamix_sales.csv"  # Specific file to load
)

# Convert the 'Time' column to datetime format and store it in a new column 'Date'
data['Date'] = pd.to_datetime(data['Time'], format='%d/%m/%y')

# Drop the original 'Time' column as it's now redundant
data = data.drop(columns=['Time'], axis=1)

# Remove any duplicate rows from the dataset
data = data.drop_duplicates()
data = data.sort_values(by=['Date'],ascending=True)

# Display the first few rows of the cleaned dataset
data.head()
# Out:
#    tv_sponsorships  tv_cricket  tv_RON  radio    NPP  Magazines  OOH   Social  \
# 0          119.652      66.729  43.719   37.8  55.36      13.84   35  41.8782
# 1           23.140      12.905   8.455   39.3  36.08       9.02   35   8.0990
# 2            8.944       4.988   3.268   45.9  55.44      13.86   35   3.1304
# 3           78.780      43.935  28.785   41.3  46.80      11.70   35  27.5730
# 4           94.016      52.432  34.352   10.8  46.72      11.68   35  32.9056
#
#    Programmatic  Display_Rest     Search  Native  sales       Date
# 0             5      33.50256  26.802048       5  22100 2001-01-01
# 1             5       6.47920   5.183360       6  10400 2001-02-01
# 2             5       2.50432   2.003456       7   9300 2001-03-01
# 3             5      22.05840  17.646720       5  18500 2001-04-01
# 4             5      26.32448  21.059584       7  12900 2001-05-01

# %%
# media variables - spends 
media_cols=['tv_sponsorships', 'tv_cricket', 'tv_RON', 'radio', 'NPP', 'Magazines',
       'OOH', 'Social', 'Programmatic', 'Display_Rest', 'Search', 'Native']

# dependent variable
dv =['sales']

# %%
SEED = 42
data_size = len(data)

n_media_channels = len(media_cols)
n_extra_features = 0
media_data = data[media_cols].to_numpy()
target = data['sales'].to_numpy()
costs = data[media_cols].sum().to_numpy()

# Split and scale data.
test_data_period_size = 24
split_point = data_size - test_data_period_size
# Media data
media_data_train = media_data[:split_point, ...]
media_data_test = media_data[split_point:, ...]

# Target
target_train = target[:split_point]


media_scaler = preprocessing.CustomScaler(divide_operation=jnp.mean)
target_scaler = preprocessing.CustomScaler(divide_operation=jnp.mean)
cost_scaler = preprocessing.CustomScaler(divide_operation=jnp.mean, multiply_by=0.15)

media_data_train = media_scaler.fit_transform(media_data_train)
target_train = target_scaler.fit_transform(target_train)
costs = cost_scaler.fit_transform(costs)





mmm = lightweight_mmm.LightweightMMM(model_name="hill_adstock")
mmm.fit( media=media_data_train, media_prior=costs, target=target_train, media_names = media_cols, seed=SEED)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 25
#      22 target_scaler = preprocessing.CustomScaler(divide_operation=jnp.mean)
#      23 cost_scaler = preprocessing.CustomScaler(divide_operation=jnp.mean, multiply_by=0.15)
# ---> 25 media_data_train = media_scaler.fit_transform(media_data_train)
#      26 target_train = target_scaler.fit_transform(target_train)
#      27 costs = cost_scaler.fit_transform(costs)
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\lightweight_mmm\preprocessing.py:149, in CustomScaler.fit_transform(self, data)
#     140 def fit_transform(self, data: jnp.ndarray) -> jnp.ndarray:
#     141   """Fits the values and applies transformation to the input data.
#     142
#     143   Args:
#    (...)    147     Transformed array.
#     148   """
# --> 149   self.fit(data)
#     150   return self.transform(data)
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\lightweight_mmm\preprocessing.py:112, in CustomScaler.fit(self, data)
#     106 """Figures out values for transformations based on the specified operations.
#     107
#     108 Args:
#     109   data: Input dataset to use for fitting.
#     110 """
#     111 if hasattr(self, "divide_operation"):
# --> 112   self.divide_by = jnp.apply_along_axis(
#     113       func1d=self.divide_operation, axis=0, arr=data)
#     114 elif isinstance(self.divide_by, int) or isinstance(self.divide_by, float):
#     115   self.divide_by = self.divide_by * jnp.ones(data.shape[1:])
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\jax\_src\numpy\lax_numpy.py:7874, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#    7872 for i in range(axis):
#    7873   func = api.vmap(func, in_axes=0, out_axes=0)
# -> 7874 return func(arr)
#
#     [... skipping hidden 7 frame]
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\jax\_src\numpy\lax_numpy.py:7869, in apply_along_axis.<locals>.<lambda>(arr)
#    7867 num_dims = np.ndim(arr)
#    7868 axis = _canonicalize_axis(axis, num_dims)
# -> 7869 func = lambda arr: func1d(arr, *args, **kwargs)
#    7870 for i in range(1, num_dims - axis):
#    7871   func = api.vmap(func, in_axes=i, out_axes=-1)
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\jax\_src\numpy\reductions.py:866, in mean(a, axis, dtype, out, keepdims, where)
#     802 @export
#     803 def mean(a: ArrayLike, axis: Axis = None, dtype: DTypeLike | None = None,
#     804          out: None = None, keepdims: bool = False, *,
#     805          where: ArrayLike | None = None) -> Array:
#     806   r"""Return the mean of array elements along a given axis.
#     807
#     808   JAX implementation of :func:`numpy.mean`.
#    (...)    864            [6. ]], dtype=float32)
#     865   """
# --> 866   return _mean(a, _ensure_optional_axes(axis), dtype, out, keepdims,
#     867                where=where, upcast_f16_for_computation=(dtype is None))
#
#     [... skipping hidden 15 frame]
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\jax\_src\numpy\reductions.py:907, in _mean(a, axis, dtype, out, keepdims, upcast_f16_for_computation, where)
#     904 else:
#     905   computation_dtype = result_dtype
# --> 907 normalizer = _count(
#     908     a,
#     909     axis=axis,
#     910     keepdims=keepdims,
#     911     where=where,
#     912     dtype=computation_dtype,
#     913 )
#     915 return lax.div(
#     916     sum(a, axis, dtype=computation_dtype, keepdims=keepdims, where=where),
#     917     normalizer,
#     918 ).astype(result_dtype)
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\jax\_src\numpy\reductions.py:881, in _count(a, axis, keepdims, where, dtype)
#     879   else:
#     880     count = core.dimension_as_value(_axis_size(a, axis))
# --> 881   count = lax.convert_element_type(count, dtype)
#     882 else:
#     883   count = sum(_broadcast_to(where, np.shape(a)), axis, dtype=dtype, keepdims=keepdims)
#
#     [... skipping hidden 10 frame]
#
# File ~\miniconda3\envs\mmm\Lib\site-packages\jax\_src\literals.py:161, in TypedNdArray.__array__(self, dtype, copy)
#     154 def __array__(self, dtype=None, copy=None):
#     155   # You might think that we can do the following here:
#     156   # return self.val.__array__(dtype=dtype, copy=copy)
#    (...)    159   # TODO(phawkins): revert to the above form once NumPy 2.3 is the minimum
#     160   # supported version.
# --> 161   return np.asarray(self.val, dtype=dtype, copy=copy)
#
# TypeError: asarray() got an unexpected keyword argument 'copy'
